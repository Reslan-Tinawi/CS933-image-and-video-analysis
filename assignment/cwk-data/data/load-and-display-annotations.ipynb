# %%
# this notebook may be useful to solve Part 3 of the 
# CS413 coursework assignment 2023-24
import os
import glob


import numpy as np
import matplotlib.pyplot as plt

import xmltodict

import cv2

# %%
# data_dir = '/Users/abhir/Desktop/AOI/data/' # where you've put the cwk data files
data_dir = '../data/'

annotations_dir = data_dir + 'ANNOTATIONS/'

# name the annotation file you want to load and show
xml_filename = annotations_dir + 'BOARD3-1.xml'


with open(xml_filename) as xml_file:
    data_dict = xmltodict.parse(xml_file.read())
    
    
# see what information we have in the data_dict
print(data_dict)
# Out:
# {'annotation': {'folder': 'BOARDS', 'filename': 'BOARD3-1.jpg', 'path': '/Users/abhir/Desktop/AOI/data/BOARDS/BOARD3-1.jpg', 'source': {'database': 'Unknown'}, 'size': {'width': '4032', 'height': '3024', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'enet', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '2074', 'ymin': '1286', 'xmax': '2199', 'ymax': '1412'}}, {'name': 'regulator', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '2475', 'ymin': '1670', 'xmax': '2658', 'ymax': '1825'}}, {'name': 'regulator', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '2438', 'ymin': '1881', 'xmax': '2636', 'ymax': '2030'}}, {'name': 'osc1', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '1449', 'ymin': '1049', 'xmax': '1604', 'ymax': '1221'}}, {'name': 'buck', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '1279', 'ymin': '1115', 'xmax': '1375', 'ymax': '1214'}}, {'name': 'buck', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '1088', 'ymin': '1841', 'xmax': '1185', 'ymax': '1946'}}, {'name': 'rect', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '1651', 'ymin': '1289', 'xmax': '1848', 'ymax': '1360'}}, {'name': 'rect', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '1656', 'ymin': '1394', 'xmax': '1843', 'ymax': '1468'}}, {'name': 'rect', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '1653', 'ymin': '1512', 'xmax': '1841', 'ymax': '1574'}}, {'name': 'osc2', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '2379', 'ymin': '1143', 'xmax': '2480', 'ymax': '1297'}}, {'name': 'dac', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '1120', 'ymin': '1521', 'xmax': '1330', 'ymax': '1758'}}, {'name': 'transistor', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '1912', 'ymin': '1669', 'xmax': '2008', 'ymax': '1756'}}, {'name': 'con', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '1600', 'ymin': '1808', 'xmax': '1888', 'ymax': '2062'}}, {'name': 'cap1', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '1185', 'ymin': '1060', 'xmax': '1259', 'ymax': '1093'}}, {'name': 'cap1', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '1277', 'ymin': '1063', 'xmax': '1349', 'ymax': '1097'}}, {'name': 'cap1', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '1391', 'ymin': '1128', 'xmax': '1426', 'ymax': '1197'}}, {'name': 'cap1', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '1321', 'ymin': '1233', 'xmax': '1385', 'ymax': '1265'}}, {'name': 'cap1', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '1251', 'ymin': '1478', 'xmax': '1323', 'ymax': '1513'}}, {'name': 'cap1', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '1341', 'ymin': '1483', 'xmax': '1413', 'ymax': '1516'}}, {'name': 'cap1', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '1068', 'ymin': '1545', 'xmax': '1101', 'ymax': '1607'}}, {'name': 'cap1', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '1345', 'ymin': '1615', 'xmax': '1371', 'ymax': '1682'}}, {'name': 'cap1', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '1342', 'ymin': '1717', 'xmax': '1371', 'ymax': '1780'}}, {'name': 'cap1', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '1117', 'ymin': '1798', 'xmax': '1184', 'ymax': '1827'}}, {'name': 'cap1', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '1748', 'ymin': '1603', 'xmax': '1815', 'ymax': '1637'}}, {'name': 'cap1', 'pose': 'Unspecified', 'truncated': '0', 'difficu ...

# %%
from matplotlib.patches import Rectangle

# tease out some information

# the image this file contains annotation for is...
# (note don't use 'path' as it's absolute to the creator)
folder = data_dict['annotation']['folder']
filename = data_dict['annotation']['filename']

image_path = data_dir + folder + '/' + filename
width = data_dict['annotation']['size']['width']
height = data_dict['annotation']['size']['height']

# these are a list of bbox annotations with labels, coordinates
objects = data_dict['annotation']['object']

print('image_path', image_path, ', width', width, ', height', height)
print('num of annotation objects', len(objects))


# load the image which is referred to in the annotation file
image = cv2.imread(image_path)
print('loaded image has shape', image.shape)


fig = plt.figure(figsize=(20,10))
ax = plt.subplot(111)

plt.imshow(image)

for i in range(len(objects)):
    
    label = objects[i]['name']
    bbox_info = objects[i]['bndbox'] 
    
    # need to make the coords into integers...
    bbox = (int(bbox_info['xmin']), 
            int(bbox_info['ymin']), 
            int(bbox_info['xmax']), 
            int(bbox_info['ymax'])) # bbox ntuple
    
    print('bbox', i, ', has label = ', label, ', bbox = ', bbox)
    
    # overlay the annotation as a rectangle
    ax.add_patch(Rectangle((bbox[0], bbox[1]), bbox[2]-bbox[0], bbox[3]-bbox[1],
                 edgecolor = 'red',
                 facecolor = 'None',
                 fill=True,
                 lw=1))    
    
    
plt.show()
# Out:
# image_path ../data/BOARDS/BOARD3-1.jpg , width 4032 , height 3024
# num of annotation objects 113
# loaded image has shape (3024, 4032, 3)
# bbox 0 , has label =  enet , bbox =  (2074, 1286, 2199, 1412)
# bbox 1 , has label =  regulator , bbox =  (2475, 1670, 2658, 1825)
# bbox 2 , has label =  regulator , bbox =  (2438, 1881, 2636, 2030)
# bbox 3 , has label =  osc1 , bbox =  (1449, 1049, 1604, 1221)
# bbox 4 , has label =  buck , bbox =  (1279, 1115, 1375, 1214)
# bbox 5 , has label =  buck , bbox =  (1088, 1841, 1185, 1946)
# bbox 6 , has label =  rect , bbox =  (1651, 1289, 1848, 1360)
# bbox 7 , has label =  rect , bbox =  (1656, 1394, 1843, 1468)
# bbox 8 , has label =  rect , bbox =  (1653, 1512, 1841, 1574)
# bbox 9 , has label =  osc2 , bbox =  (2379, 1143, 2480, 1297)
# bbox 10 , has label =  dac , bbox =  (1120, 1521, 1330, 1758)
# bbox 11 , has label =  transistor , bbox =  (1912, 1669, 2008, 1756)
# bbox 12 , has label =  con , bbox =  (1600, 1808, 1888, 2062)
# bbox 13 , has label =  cap1 , bbox =  (1185, 1060, 1259, 1093)
# bbox 14 , has label =  cap1 , bbox =  (1277, 1063, 1349, 1097)
# bbox 15 , has label =  cap1 , bbox =  (1391, 1128, 1426, 1197)
# bbox 16 , has label =  cap1 , bbox =  (1321, 1233, 1385, 1265)
# bbox 17 , has label =  cap1 , bbox =  (1251, 1478, 1323, 1513)
# bbox 18 , has label =  cap1 , bbox =  (1341, 1483, 1413, 1516)
# bbox 19 , has label =  cap1 , bbox =  (1068, 1545, 1101, 1607)
# bbox 20 , has label =  cap1 , bbox =  (1345, 1615, 1371, 1682)
# bbox 21 , has label =  cap1 , bbox =  (1342, 1717, 1371, 1780)
# bbox 22 , has label =  cap1 , bbox =  (1117, 1798, 1184, 1827)
# bbox 23 , has label =  cap1 , bbox =  (1748, 1603, 1815, 1637)
# bbox 24 , has label =  cap1 , bbox =  (2208, 1232, 2271, 1269)
# bbox 25 , has label =  cap1 , bbox =  (2291, 1235, 2354, 1269)
# bbox 26 , has label =  cap1 , bbox =  (2234, 1291, 2297, 1323)
# bbox 27 , has label =  cap1 , bbox =  (2227, 1393, 2301, 1426)
# bbox 28 , has label =  cap1 , bbox =  (2037, 1427, 2099, 1461)
# bbox 29 , has label =  cap1 , bbox =  (2039, 1545, 2072, 1603)
# bbox 30 , has label =  cap1 , bbox =  (2080, 1542, 2114, 1604)
# bbox 31 , has label =  cap1 , bbox =  (2124, 1545, 2157, 1605)
# bbox 32 , has label =  cap1 , bbox =  (2173, 1579, 2237, 1615)
# bbox 33 , has label =  cap1 , bbox =  (2297, 1625, 2361, 1658)
# bbox 34 , has label =  cap1 , bbox =  (2177, 1722, 2240, 1760)
# bbox 35 , has label =  cap1 , bbox =  (2597, 1476, 2631, 1543)
# bbox 36 , has label =  cap1 , bbox =  (2421, 1681, 2448, 1746)
# bbox 37 , has label =  cap1 , bbox =  (2584, 1593, 2650, 1625)
# bbox 38 , has label =  cap1 , bbox =  (2584, 1640, 2650, 1667)
# bbox 39 , has label =  cap1 , bbox =  (2671, 1772, 2705, 1836)
# bbox 40 , has label =  cap1 , bbox =  (2357, 1997, 2421, 2032)
# bbox 41 , has label =  cap2 , bbox =  (1622, 1033, 1745, 1127)
# bbox 42 , has label =  cap2 , bbox =  (2290, 1666, 2374, 1717)
# bbox 43 , has label =  cap1 , bbox =  (2498, 1175, 2527, 1241)
# bbox 44 , has label =  resistor , bbox =  (1189, 1105, 1264, 1138)
# bbox 45 , has label =  resistor , bbox =  (1189, 1187, 1218, 1255)
# bbox 46 , has label =  resistor , bbox =  (1233, 1185, 1265, 1255)
# bbox 47 , has label =  resistor , bbox =  (1664, 1233, 1739, 1270)
# bbox 48 , has label =  resistor , bbox =  (1210, 1777, 1243, 1844)
# bbox 49 , has label =  resistor , bbox =  (1257, 1775, 1292, 1847)
# bbox 50 , has label =  resistor , bbox =  (1085, 1955, 1177, 1987)
# bbox 51 , has label =  resistor , bbox =  (1087, 1996, 1176, 2028)
# bbox 52 , has label =  resistor , bbox =  (1776, 1036, 1846, 1073)
# bbox 53 , has label =  resistor , bbox =  (1864, 1045, 1899, 1119)
# bbox 54 , has label =  resistor , bbox =  (1914, 1042, 1983, 1078)
# bbox 55 , has label =  resistor , bbox =  (1918, 1118, 1992, 1150)
# bbox 56 , has label =  resistor , bbox =  (2004, 1175, 2074, 1207)
# bbox 57 , has label =  resistor , bbox =  (2122, 1175, 2193, 1212)
# bbox 58 , has label =  resistor , bbox =  (2227, 1335, 2298, 1365)
# bbox 59 , has label =  resistor , bbox =  (2228, 1435, 2295, 1469)
# bbox 60 , has label =  resistor , bbox =  (2653, 1081, 2721, 1112)
# bbox 61 , has label =  resistor , bbox =  (2651, 1123, 2720, 1155)
# bbox 62 , has label =  resistor , bbox =  (2652, 1257, 2717, 1291)
# bbox 63 , has label =  resistor , bbox =  (2650, 1302, 2715, 1334)
# bbox 64 , has label =  resistor , bbox =  (2641, 1474, 2679, 1547)
# bbox 65 , has label =  resistor , bbox =  (2686, 1475, 2719, 1548)
# bbox 66 , has label =  resistor , bbox =  (1911, 1520, 1944, 1592)
# bbox 67 , has label =  resistor , bbox =  (1954, 1520, 1987, 1592)
# bbox 68 , has label =  resistor , bbox =  (1996, 1522, 2032, 1593)
# bbox 69 , has label =  resistor , bbox =  (2016, 1670, 2088, 1708)
# bbox 70 , has label =  resistor , bbox =  (2017, 1718, 2087, 1752)
# bbox 71 , has label =  resistor , bbox =  (2257, 1722, 2325, 1764)
# bbox 72 , has label =  resistor , bbox =  (2668, 1687, 2706, 1755)
# bbox 73 , has label =  resistor , bbox =  (2714, 1686, 2748, 1755)
# bbox 74 , has label =  resistor , bbox =  (2652, 1997, 2725, 2032)
# bbox 75 , has label =  unknown3 , bbox =  (2864, 1572, 2934, 1612)
# bbox 76 , has label =  unknown , bbox =  (1761, 1085, 1842, 1140)
# bbox 77 , has label =  unknown2 , bbox =  (1797, 1238, 1867, 1270)
# bbox 78 , has label =  jumpers , bbox =  (1941, 1871, 2316, 1965)
# bbox 79 , has label =  con2 , bbox =  (3077, 1611, 3239, 2093)
# bbox 80 , has label =  con3 , bbox =  (2741, 1021, 3521, 1548)
# bbox 81 , has label =  con4 , bbox =  (1435, 1242, 1614, 1995)
# bbox 82 , has label =  pcb , bbox =  (1012, 980, 3526, 2104)
# bbox 83 , has label =  text , bbox =  (1257, 1975, 1330, 2018)
# bbox 84 , has label =  text , bbox =  (1394, 1050, 1428, 1116)
# bbox 85 , has label =  text , bbox =  (1622, 1124, 1725, 1176)
# bbox 86 , has label =  text , bbox =  (1922, 1149, 1987, 1191)
# bbox 87 , has label =  text , bbox =  (1619, 1625, 1852, 1783)
# bbox 88 , has label =  text , bbox =  (1992, 1013, 2583, 1131)
# bbox 89 , has label =  text , bbox =  (2393, 1310, 2595, 1549)
# bbox 90 , has label =  text , bbox =  (2392, 1360, 2722, 1464)
# bbox 91 , has label =  text , bbox =  (1900, 1448, 2030, 1516)
# bbox 92 , has label =  text , bbox =  (1968, 1779, 2087, 1865)
# bbox 93 , has label =  text , bbox =  (2172, 1779, 2287, 1876)
# bbox 94 , has label =  text , bbox =  (2117, 1970, 2214, 2051)
# bbox 95 , has label =  text , bbox =  (2655, 1921, 2768, 1970)
# bbox 96 , has label =  text , bbox =  (2388, 1563, 2584, 1678)
# bbox 97 , has label =  text , bbox =  (2400, 1813, 2518, 1869)
# bbox 98 , has label =  text , bbox =  (2829, 1656, 3069, 2054)
# bbox 99 , has label =  text , bbox =  (2597, 1358, 2722, 1465)
# bbox 100 , has label =  text , bbox =  (2570, 1058, 2655, 1326)
# bbox 101 , has label =  text , bbox =  (1035, 1820, 1084, 2031)
# bbox 102 , has label =  hole , bbox =  (1255, 1280, 1348, 1379)
# bbox 103 , has label =  hole , bbox =  (1244, 1865, 1329, 1961)
# bbox 104 , has label =  hole , bbox =  (2962, 1603, 3054, 1691)
# bbox 105 , has label =  tracks , bbox =  (2135, 1466, 2387, 1548)
# bbox 106 , has label =  tracks , bbox =  (1927, 1211, 2079, 1423)
# bbox 107 , has label =  tracks , bbox =  (1168, 1534, 1278, 1753)
# bbox 108 , has label =  tracks , bbox =  (1182, 1346, 1405, 1456)
# bbox 109 , has label =  tracks , bbox =  (1898, 1984, 2294, 2064)
# bbox 110 , has label =  tracks , bbox =  (2643, 1833, 2749, 1989)
# bbox 111 , has label =  tracks , bbox =  (2374, 1304, 2580, 1558)
# bbox 112 , has label =  tracks , bbox =  (2019, 1088, 2373, 1174)
